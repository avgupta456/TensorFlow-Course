# %%
import tensorflow as tf
import numpy as np

import matplotlib.pyplot as plt

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.995):
            print("Reaching 99.5% accuracy, cancelling training!\n")
            self.model.stop_training=True
            
callbacks = myCallback()

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10, callbacks=[callbacks])
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.2598 - accuracy: 0.9262
# Epoch 2/10
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.1163 - accuracy: 0.9656
# Epoch 3/10
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.0796 - accuracy: 0.9762
# Epoch 4/10
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.0613 - accuracy: 0.9819
# Epoch 5/10
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0481 - accuracy: 0.9855
# Epoch 6/10
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0372 - accuracy: 0.9888
# Epoch 7/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0310 - accuracy: 0.9900
# Epoch 8/10
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0240 - accuracy: 0.9927
# Epoch 9/10
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.0206 - accuracy: 0.9936
# Epoch 10/10
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0172 - accuracy: 0.9948

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.08178035725109076, 0.9788]
